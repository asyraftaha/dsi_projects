# %% [markdown]
# This notebook is to show the local deployment code of my model using the Telegram Bot.
#
# Note: The development of this bot is unrefined and has many rooms for improvement in Error Handling.

# %%
import pickle
import telebot
import numpy as np
import pandas as pd
from telebot import types

API_TOKEN = 'Your_Token Here'

bot = telebot.TeleBot(API_TOKEN)

model = pickle.load(open('../model/finalized_model.sav', 'rb'))

X = {}
train = pd.DataFrame(columns=['mileage','coe','curb_weight','transmission','omv','num_owners',
                          'coe_balance_in_months','COECar','PARFCar','other_cat','audi','bmw','honda','hyundai',
                          'kia','lexus','mazda','mercedes-benz','mitsubishi','nissan','other_makes','subaru',
                          'suzuki','toyota','volkswagen','volvo','Hatchback','Luxury Sedan','MPV','Mid-Sized Sedan',
                          'SUV','other_type'])



@bot.message_handler(commands=['help', 'start'])

def start(message):
    msg = bot.reply_to(message, """
    \
    "What is the current mileage of your car?(Please only reply in numbers.)"
    """)
    bot.register_next_step_handler(msg, mileage)


def mileage(message):
    mileage = int(message.text)
    if not message.text.isdigit():
        msg = bot.reply_to(message, 'Your reply should be a number. Please type your response again.')
        bot.register_next_step_handler(msg, mileage)
        return
    X['mileage'] = mileage
    msg = bot.reply_to(message, "What was your COE price you've bought at? (Please only reply in numbers.)")
    bot.register_next_step_handler(msg, coe)

def coe(message):
    coe = int(message.text)
    if not message.text.isdigit():
        msg = bot.reply_to(message, 'Your reply should be a number. Please type your response again.')
        bot.register_next_step_handler(msg, coe)
        return
    X['coe'] = coe
    msg = bot.reply_to(message, "What is the Curb Weight of your Car? (Please only reply in numbers.)")
    bot.register_next_step_handler(msg, curb_weight)

def curb_weight(message):
    curb_weight = int(message.text)
    if not message.text.isdigit():
        msg = bot.reply_to(message, 'Your reply should be a number. Please type your response again.')
        bot.register_next_step_handler(msg, curb_weight)
        return
    X['curb_weight'] = curb_weight
    markup = types.ReplyKeyboardMarkup(one_time_keyboard=True)
    markup.add('Auto', 'Manual')
    msg = bot.reply_to(message, 'What is the transmission of your car?', reply_markup=markup)
    bot.register_next_step_handler(msg, transmission)

def transmission(message):
    transmission = message.text
    if (transmission == u'Auto'):
        X['transmission'] = 1
    else:
        X['transmission'] = 0
    msg = bot.reply_to(message, "What is the Open Market Value(OMV) of your Car? (Please only reply in numbers.)")
    bot.register_next_step_handler(msg, omv)

def omv(message):
    omv = int(message.text)
    if not message.text.isdigit():
        msg = bot.reply_to(message, 'Your reply should be a number. Please type your response again.')
        bot.register_next_step_handler(msg, omv)
        return
    X['omv'] = omv
    msg = bot.reply_to(message, 'How many owner(s), including yourself, does the car have? (Please only reply in numbers.)')
    bot.register_next_step_handler(msg, num_owners)        
            
def num_owners(message):
    num_owners = int(message.text)
    if not message.text.isdigit():
        msg = bot.reply_to(message, 'Your reply should be a number. Please type your response again.')
        bot.register_next_step_handler(msg, num_owners)
        return
    X['num_owners'] = num_owners
    msg = bot.reply_to(message, "What is the balance of your COE? Please indicate the balance in months. (Example reply '12' if the COE balance is a year.)")
    bot.register_next_step_handler(msg, coe_balance) 

def coe_balance(message):
    coe_balance = int(message.text)
    if not message.text.isdigit():
        msg = bot.reply_to(message, 'Your reply should be a number. Please type your response again.')
        bot.register_next_step_handler(msg, coe_balance)
        return
    X['coe_balance_in_months'] = coe_balance
    markup = types.ReplyKeyboardMarkup(one_time_keyboard=True)
    markup.add('audi', 'bmw', 'honda','hyundai','kia','lexus','mazda','mercedes-benz',
               'mitsubishi','nissan','subaru','suzuki','toyota','volkswagen','volvo','others')
    msg = bot.reply_to(message, 'What is the make of your car? (Indicate only the make of your car)', reply_markup=markup)
    bot.register_next_step_handler(msg, make)      
        
def make(message):
    make = message.text
    if (make == u'audi'):
        X['audi'] = 1
        X['bmw'] = 0
        X['honda'] = 0
        X['hyundai'] = 0
        X['kia'] = 0
        X['lexus'] = 0
        X['mazda'] = 0
        X['mercedes-benz'] = 0
        X['mitsubishi'] = 0
        X['nissan'] = 0  
        X['subaru'] = 0
        X['suzuki'] = 0
        X['toyota'] = 0
        X['volkswagen'] = 0
        X['volvo'] = 0
        X['other_makes'] = 0
            
    elif (make == u'bmw'):
        X['audi'] = 0
        X['bmw'] = 1
        X['honda'] = 0
        X['hyundai'] = 0
        X['kia'] = 0
        X['lexus'] = 0
        X['mazda'] = 0
        X['mercedes-benz'] = 0
        X['mitsubishi'] = 0
        X['nissan'] = 0
        X['subaru'] = 0
        X['suzuki'] = 0
        X['toyota'] = 0
        X['volkswagen'] = 0
        X['volvo'] = 0
        X['other_makes'] = 0
            
    elif (make == u'honda'):
        X['audi'] = 0
        X['bmw'] = 0
        X['honda'] = 1
        X['hyundai'] = 0
        X['kia'] = 0
        X['lexus'] = 0
        X['mazda'] = 0
        X['mercedes-benz'] = 0
        X['mitsubishi'] = 0
        X['nissan'] = 0
        X['subaru'] = 0
        X['suzuki'] = 0
        X['toyota'] = 0
        X['volkswagen'] = 0
        X['volvo'] = 0
        X['other_makes'] = 0
            
    elif (make == u'hyundai'):
        X['audi'] = 0
        X['bmw'] = 0
        X['honda'] = 0
        X['hyundai'] = 1
        X['kia'] = 0
        X['lexus'] = 0
        X['mazda'] = 0
        X['mercedes-benz'] = 0
        X['mitsubishi'] = 0
        X['nissan'] = 0
        X['subaru'] = 0
        X['suzuki'] = 0
        X['toyota'] = 0
        X['volkswagen'] = 0
        X['volvo'] = 0
        X['other_makes'] = 0
            
    elif (make == u'kia'):
        X['audi'] = 0
        X['bmw'] = 0
        X['honda'] = 0
        X['hyundai'] = 0
        X['kia'] = 1
        X['lexus'] = 0
        X['mazda'] = 0
        X['mercedes-benz'] = 0
        X['mitsubishi'] = 0
        X['nissan'] = 0
        X['subaru'] = 0
        X['suzuki'] = 0
        X['toyota'] = 0
        X['volkswagen'] = 0
        X['volvo'] = 0
        X['other_makes'] = 0
            
    elif (make == u'lexus'):
        X['audi'] = 0
        X['bmw'] = 0
        X['honda'] = 0
        X['hyundai'] = 0
        X['kia'] = 0
        X['lexus'] = 1
        X['mazda'] = 0
        X['mercedes-benz'] = 0
        X['mitsubishi'] = 0
        X['nissan'] = 0
        X['subaru'] = 0
        X['suzuki'] = 0
        X['toyota'] = 0
        X['volkswagen'] = 0
        X['volvo'] = 0
        X['other_makes'] = 0
            
    elif (make == u'mazda'):
        X['audi'] = 0
        X['bmw'] = 0
        X['honda'] = 0
        X['hyundai'] = 0
        X['kia'] = 0
        X['lexus'] = 0
        X['mazda'] = 1
        X['mercedes-benz'] = 0
        X['mitsubishi'] = 0
        X['nissan'] = 0
        X['subaru'] = 0
        X['suzuki'] = 0
        X['toyota'] = 0
        X['volkswagen'] = 0
        X['volvo'] = 0
        X['other_makes'] = 0

    elif (make == u'mercedes-benz'):
        X['audi'] = 0
        X['bmw'] = 0
        X['honda'] = 0
        X['hyundai'] = 0
        X['kia'] = 0
        X['lexus'] = 0
        X['mazda'] = 0
        X['mercedes-benz'] = 1
        X['mitsubishi'] = 0
        X['nissan'] = 0
        X['subaru'] = 0
        X['suzuki'] = 0
        X['toyota'] = 0
        X['volkswagen'] = 0
        X['volvo'] = 0
        X['other_makes'] = 0    
            
    elif (make == u'mitsubishi'):
        X['audi'] = 0
        X['bmw'] = 0
        X['honda'] = 0
        X['hyundai'] = 0
        X['kia'] = 0
        X['lexus'] = 0
        X['mazda'] = 0
        X['mercedes-benz'] = 0
        X['mitsubishi'] = 1
        X['nissan'] = 0
        X['subaru'] = 0
        X['suzuki'] = 0
        X['toyota'] = 0
        X['volkswagen'] = 0
        X['volvo'] = 0
        X['other_makes'] = 0
        
    elif (make == u'nissan'):
        X['audi'] = 0
        X['bmw'] = 0
        X['honda'] = 0
        X['hyundai'] = 0
        X['kia'] = 0
        X['lexus'] = 0
        X['mazda'] = 0
        X['mercedes-benz'] = 0
        X['mitsubishi'] = 0
        X['nissan'] = 1
        X['subaru'] = 0
        X['suzuki'] = 0
        X['toyota'] = 0
        X['volkswagen'] = 0
        X['volvo'] = 0
        X['other_makes'] = 0
        
    elif (make == u'subaru'):
        X['audi'] = 0
        X['bmw'] = 0
        X['honda'] = 0
        X['hyundai'] = 0
        X['kia'] = 0
        X['lexus'] = 0
        X['mazda'] = 0
        X['mercedes-benz'] = 0
        X['mitsubishi'] = 0
        X['nissan'] = 0
        X['subaru'] = 1
        X['suzuki'] = 0
        X['toyota'] = 0
        X['volkswagen'] = 0
        X['volvo'] = 0
        X['other_makes'] = 0
        
    elif (make == u'suzuki'):
        X['audi'] = 0
        X['bmw'] = 0
        X['honda'] = 0
        X['hyundai'] = 0
        X['kia'] = 0
        X['lexus'] = 0
        X['mazda'] = 0
        X['mercedes-benz'] = 0
        X['mitsubishi'] = 0
        X['nissan'] = 0
        X['subaru'] = 0
        X['suzuki'] = 1
        X['toyota'] = 0
        X['volkswagen'] = 0
        X['volvo'] = 0
        X['other_makes'] = 0
        
    elif (make == u'toyota'):
        X['audi'] = 0
        X['bmw'] = 0
        X['honda'] = 0
        X['hyundai'] = 0
        X['kia'] = 0
        X['lexus'] = 0
        X['mazda'] = 0
        X['mercedes-benz'] = 0
        X['mitsubishi'] = 0
        X['nissan'] = 0
        X['subaru'] = 0
        X['suzuki'] = 0
        X['toyota'] = 1
        X['volkswagen'] = 0
        X['volvo'] = 0
        X['other_makes'] = 0
        
    elif (make == u'volkswagen'):
        X['audi'] = 0
        X['bmw'] = 0
        X['honda'] = 0
        X['hyundai'] = 0
        X['kia'] = 0
        X['lexus'] = 0
        X['mazda'] = 0
        X['mercedes-benz'] = 0
        X['mitsubishi'] = 0
        X['nissan'] = 0
        X['subaru'] = 0
        X['suzuki'] = 0
        X['toyota'] = 0
        X['volkswagen'] = 1
        X['volvo'] = 0
        X['other_makes'] = 0
        
    elif (make == u'volvo'):
        X['audi'] = 0
        X['bmw'] = 0
        X['honda'] = 0
        X['hyundai'] = 0
        X['kia'] = 0
        X['lexus'] = 0
        X['mazda'] = 0
        X['mercedes-benz'] = 0
        X['mitsubishi'] = 0
        X['nissan'] = 0
        X['subaru'] = 0
        X['suzuki'] = 0
        X['toyota'] = 0
        X['volkswagen'] = 0
        X['volvo'] = 1
        X['other_makes'] = 0
            
    elif (make == u'other_makes'):
        X['audi'] = 0
        X['bmw'] = 0
        X['honda'] = 0
        X['hyundai'] = 0
        X['kia'] = 0
        X['lexus'] = 0
        X['mazda'] = 0
        X['mercedes-benz'] = 0
        X['mitsubishi'] = 0
        X['nissan'] = 0
        X['subaru'] = 0
        X['suzuki'] = 0
        X['toyota'] = 0
        X['volkswagen'] = 0
        X['volvo'] = 0
        X['other_makes'] = 1
        
    markup = types.ReplyKeyboardMarkup(one_time_keyboard=True)
    markup.add('Hatchback','Luxury Sedan','MPV','Mid-Sized Sedan','SUV','Others')
    msg = bot.reply_to(message, 'What is the type of your car?', reply_markup=markup)
    bot.register_next_step_handler(msg, type)
                
def type(message):
    type = message.text
    if (type == u'Hatchback'):
        X['Hatchback'] = 1
        X['Luxury Sedan'] = 0
        X['MPV'] = 0
        X['Mid-Sized Sedan'] = 0
        X['SUV'] = 0
        X['other_type'] = 0
            
    elif (type == u'Luxury Sedan'):
        X['Hatchback'] = 0
        X['Luxury Sedan'] = 1
        X['MPV'] = 0
        X['Mid-Sized Sedan'] = 0
        X['SUV'] = 0
        X['other_type'] = 0
            
    elif (type == u'MPV'):
        X['Hatchback'] = 0
        X['Luxury Sedan'] = 0
        X['MPV'] = 1
        X['Mid-Sized Sedan'] = 0
        X['SUV'] = 0
        X['other_type'] = 0
            
    elif (type == u'Mid-Sized Sedan'):
        X['Hatchback'] = 0
        X['Luxury Sedan'] = 0
        X['MPV'] = 0
        X['Mid-Sized Sedan'] = 1
        X['SUV'] = 0
        X['other_type'] = 0
            
    elif (type == u'SUV'):
        X['Hatchback'] = 0
        X['Luxury Sedan'] = 0
        X['MPV'] = 0
        X['Mid-Sized Sedan'] = 0
        X['SUV'] = 1
        X['other_type'] = 0   
        
    elif (type == u'Others'):
        X['Hatchback'] = 0
        X['Luxury Sedan'] = 0
        X['MPV'] = 0
        X['Mid-Sized Sedan'] = 0
        X['SUV'] = 0
        X['other_type'] = 1
       
    markup = types.ReplyKeyboardMarkup(one_time_keyboard=True)
    markup.add('COECar','PARFCar','Others')
    msg = bot.reply_to(message, 'What is the type of your car?', reply_markup=markup)
    bot.register_next_step_handler(msg, category) 
        
def category(message):
    category = message.text
    if (category == u'COECar'):
        X['COECar'] = 1
        X['PARFCar'] = 0
        X['other_cat'] = 0
            
    elif (category == u'PARFCar'):
        X['COECar'] = 0
        X['PARFCar'] = 1
        X['other_cat'] = 0
            
    elif (category == u'Others'):
        X['COECar'] = 0
        X['PARFCar'] = 0
        X['other_cat'] = 1
        
    y = train.append(X, ignore_index=True)
    price = model.predict(y)  
    msg = bot.reply_to(message, "Your car price is ${}".format(price[0].round(0)))
    bot.register_next_step_handler(msg, end)

def end(message):
    pass

bot.enable_save_next_step_handlers(delay=2)

bot.load_next_step_handlers()

bot.polling()

import os
from flask import Flask, request
server = Flask(__name__)

@server.route('/' + API_TOKEN, methods=['POST'])
def getMessage():
   bot.process_new_updates([telebot.types.Update.de_json(request.stream.read().decode("utf-8"))])
   return "!", 200
@server.route("/")
def webhook():
   bot.remove_webhook()
   bot.set_webhook(url='<HEROKU Web URL>' + TOKEN)
   return "!", 200
if __name__ == "__main__":
   server.run(host="0.0.0.0", port=int(os.environ.get('PORT', 5000)))
