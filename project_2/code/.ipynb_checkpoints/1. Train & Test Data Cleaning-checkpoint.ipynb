# %% [markdown]
# # 1. Train & Test Data Cleaning

# %% [markdown]
# ## Table of Content:
# - [Train DataFrame Cleaning](#Train-DataFrame-Cleaning)
# - [Test DataFrame Cleaning](#Test-DataFrame-Cleaning)

# %% [markdown]
# ## Importing libraries and packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Creating test and train csv with pandas and printing the head

# %%
test = pd.read_csv('../datasets/test.csv')
test.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour  ... 3Ssn Porch Screen Porch Pool Area Pool QC  \
# 0  Grvl       Reg          Lvl  ...          0            0         0     NaN
# 1   NaN       IR1          Lvl  ...          0            0         0     NaN
# 2   NaN       IR1          Lvl  ...          0            0         0     NaN
# 3   NaN       Reg          Lvl  ...          0            0         0     NaN
# 4   NaN       IR1          Lvl  ...          0          185         0     NaN
#
#   Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type
# ...

# %%
train = pd.read_csv('../datasets/train.csv')
train.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
# 2       Reg          Lvl  ...            0         0     NaN   NaN
# 3       Reg          Lvl  ...            0         0     NaN   NaN
# 4       IR1          Lvl  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# ...

# %%
pd.set_option('display.max_columns', 81)
pd.set_option('display.max_rows', 81)

# %% [markdown]
# ## Train DataFrame Cleaning

# %% [markdown]
# **Assigning Ordinal Values Ranking**

# %%
train[['Paved Drive']] = train[['Paved Drive']].replace(['N','P','Y'],[0,1,2])

train[['Garage Finish']] = train[['Garage Finish']].replace([np.nan,'Unf','RFn','Fin'],[0,1,2,3])

train[['Alley']] = train[['Alley']].replace(['Grvl','Pave'],[1,2])

train[['Street']] = train[['Street']].replace(['Grvl','Pave'],[1,2])

train[['Land Slope']] = train[['Land Slope']].replace(['Sev','Mod','Gtl'],[1,2,3])

train[['Central Air']] = train[['Central Air']].replace(['N','Y'],[0,1])

train[['Functional']] = train[['Functional']].replace(['Sal','Sev','Maj2','Maj1','Mod','Min2','Min1','Typ'],[1,2,3,4,5,6,7,8])

train[['Fence']] = train[['Fence']].replace([np.nan,'MnWw','GdWo','MnPrv','GdPrv'],[0,1,2,3,4])

train[['BsmtFin Type 1','BsmtFin Type 2']] = train[['BsmtFin Type 1','BsmtFin Type 2']].replace([np.nan,'Unf','LwQ','Rec','BLQ','ALQ','GLQ'],[0,1,2,3,4,5,6])

train[['Bsmt Exposure']] = train[['Bsmt Exposure']].replace([np.nan,'No','Mn','Av','Gd'],[0,1,2,3,4])

train[['Exter Qual','Exter Cond','Bsmt Qual',
      'Bsmt Cond','Heating QC','Kitchen Qual',
      'Fireplace Qu','Garage Qual','Garage Cond',
     'Pool QC']] = train[['Exter Qual','Exter Cond','Bsmt Qual',
      'Bsmt Cond','Heating QC','Kitchen Qual',
      'Fireplace Qu','Garage Qual','Garage Cond',
     'Pool QC']].replace([np.nan,'Po','Fa','TA','Gd','Ex'],[0,1,2,3,4,5])

# %% [markdown]
# **Dealing with Missing Values**

# %%
#Visualising the missing values
plt.figure(figsize = (32,20))
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis');

# %%
#Assigning variable to null values columns list
null_columns = train.columns[train.isnull().sum()>0].tolist()

# %%
#Checking list
train[null_columns].isnull().sum()
# Out:
# Lot Frontage       330
# Alley             1911
# Mas Vnr Type        22
# Mas Vnr Area        22
# BsmtFin SF 1         1
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Garage Type        113
# Garage Yr Blt      114
# Garage Cars          1
# Garage Area          1
# Misc Feature      1986
# dtype: int64

# %%
#Pairing Mas Vnr Type and Mas Vnr Area null values
train[train['Mas Vnr Type'].isnull()][['Mas Vnr Type','Mas Vnr Area']]
# Out:
#      Mas Vnr Type  Mas Vnr Area
# 22            NaN           NaN
# 41            NaN           NaN
# 86            NaN           NaN
# 212           NaN           NaN
# 276           NaN           NaN
# 338           NaN           NaN
# 431           NaN           NaN
# 451           NaN           NaN
# 591           NaN           NaN
# 844           NaN           NaN
# 913           NaN           NaN
# 939           NaN           NaN
# 1025          NaN           NaN
# 1244          NaN           NaN
# 1306          NaN           NaN
# 1430          NaN           NaN
# 1434          NaN           NaN
# 1606          NaN           NaN
# 1699          NaN           NaN
# 1815          NaN           NaN
# 1820          NaN           NaN
# 1941          NaN           NaN

# %%
#Filling null values
train['Mas Vnr Type'].fillna('None',inplace=True)
train['Mas Vnr Area'].fillna(0,inplace=True)

# %% [markdown]
# Since the Mas Vnr Type and Mas Vnr Area have the same null values, we can assume that there is indeed no Mas Vnr present for the house and can fill the values with None and 0.

# %%
train[train['Total Bsmt SF'].isnull()]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area  Street  \
# 1327  1342  903230120           20        RM          99.0      5940       2
#
#       Alley Lot Shape Land Contour Utilities Lot Config  Land Slope  \
# 1327    NaN       IR1          Lvl    AllPub        FR3           3
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 1327      BrkSide       Feedr        Norm      1Fam      1Story             4
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 1327             7        1946            1950      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area  Exter Qual  \
# 1327      MetalSd       CBlock         None           0.0           3
#
#       Exter Cond Foundation  Bsmt Qual  Bsmt Cond  Bsmt Exposure  \
# 1327           3      PConc          0          0              0
#
#       BsmtFin Type 1  BsmtFin SF 1  BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  \
# ...

# %%
train['Total Bsmt SF'].fillna(0,inplace=True)
train['BsmtFin SF 1'].fillna(0,inplace=True)
train['BsmtFin SF 2'].fillna(0,inplace=True)
train['Bsmt Unf SF'].fillna(0,inplace=True)

# %% [markdown]
# For these columns ['Total Bsmt SF','BsmtFin SF 1','BsmtFin SF 2','Bsmt Unf SF'], since there is only one null value and it coincides together in accordance to other null basement columns, we can assume that there is no basement for this observation and can fill the missing value with 0.

# %%
train[train['Bsmt Full Bath'].isnull()]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area  Street  \
# 616   1498  908154080           20        RL         123.0     47007       2
# 1327  1342  903230120           20        RM          99.0      5940       2
#
#       Alley Lot Shape Land Contour Utilities Lot Config  Land Slope  \
# 616     NaN       IR1          Lvl    AllPub     Inside           3
# 1327    NaN       IR1          Lvl    AllPub        FR3           3
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 616       Edwards        Norm        Norm      1Fam      1Story             5
# 1327      BrkSide       Feedr        Norm      1Fam      1Story             4
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 616              7        1959            1996      Gable   CompShg
# 1327             7        1946            1950      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area  Exter Qual  \
# ...

# %%
train['Bsmt Full Bath'].fillna(0,inplace=True)
train['Bsmt Half Bath'].fillna(0,inplace=True)

# %% [markdown]
# Again, from the two observations narrowed above, it is clear that for these observations, there is no basement for the house and can be filled with 0

# %%
train[train['Garage Cars'].isnull()]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area  Street  \
# 1712  2237  910201180           70        RM          50.0      9060       2
#
#       Alley Lot Shape Land Contour Utilities Lot Config  Land Slope  \
# 1712    NaN       Reg          Lvl    AllPub     Inside           3
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 1712       IDOTRR        Norm        Norm      1Fam      2Story             5
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 1712             6        1923            1999      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area  Exter Qual  \
# 1712      Wd Sdng      Plywood         None           0.0           3
#
#       Exter Cond Foundation  Bsmt Qual  Bsmt Cond  Bsmt Exposure  \
# 1712           3     BrkTil          4          3              1
#
#       BsmtFin Type 1  BsmtFin SF 1  BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  \
# ...

# %%
train['Garage Cars'].fillna(0,inplace=True)
train['Garage Area'].fillna(0,inplace=True)

# %% [markdown]
# Since Garage Cars and Garage Area null value is the same and shows no indication of a built garage, the null will be replaced with 0.

# %%
train[(train['Garage Type'].notnull()) & (train['Garage Yr Blt'].isnull())]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area  Street  \
# 1712  2237  910201180           70        RM          50.0      9060       2
#
#       Alley Lot Shape Land Contour Utilities Lot Config  Land Slope  \
# 1712    NaN       Reg          Lvl    AllPub     Inside           3
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 1712       IDOTRR        Norm        Norm      1Fam      2Story             5
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 1712             6        1923            1999      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area  Exter Qual  \
# 1712      Wd Sdng      Plywood         None           0.0           3
#
#       Exter Cond Foundation  Bsmt Qual  Bsmt Cond  Bsmt Exposure  \
# 1712           3     BrkTil          4          3              1
#
#       BsmtFin Type 1  BsmtFin SF 1  BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  \
# ...

# %%
train.drop(train.index[1712],inplace=True)

# %% [markdown]
# Since the Garage Yr Built has an extra null from the Garage Type, I have decided to drop the observation.

# %%
train[(train['Garage Type'].isnull()) & (train['Garage Yr Blt'].isnull())].shape
# Out:
# (113, 81)

# %%
train['Garage Type'].fillna('None',inplace=True)
train['Garage Yr Blt'].fillna(0,inplace=True)

# %% [markdown]
# Since the observations for Garage Type and Garage Yr Blt coincides with each other, we can deduce that there is no garage present for these observations and can fill them with 'None' and 0

# %%
sns.distplot(train['Lot Frontage'],kde=False);
# Out:
# C:\Users\asyraf\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
train['Lot Frontage'].fillna(train['Lot Frontage'].mean(),inplace=True)

# %% [markdown]
# Since the values for lot frontage cannot be equal to 0 and does not logically equals to zero, I will replace the null values with the mean lot frontage.

# %%
train.drop(columns=['Alley','Misc Feature'],inplace=True)

# %% [markdown]
# Since the null values in the columns are too big (over 90%) I have decided to drop these columns.

# %%
#Checking data values for outliers.
train.describe()
# Out:
#                 Id           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2050.000000  2.050000e+03  2050.000000   2050.000000    2050.000000
# mean   1473.661463  7.134941e+08    57.002439     69.066279   10065.698537
# std     844.018399  1.886879e+08    42.833710     21.307395    6744.097442
# min       1.000000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     753.250000  5.284581e+08    20.000000     60.000000    7500.000000
# 50%    1483.500000  5.354532e+08    50.000000     69.066279    9432.000000
# 75%    2196.500000  9.071790e+08    70.000000     78.000000   11514.250000
# max    2930.000000  9.241520e+08   190.000000    313.000000  159000.000000
#
#             Street   Land Slope  Overall Qual  Overall Cond   Year Built  \
# count  2050.000000  2050.000000   2050.000000   2050.000000  2050.000000
# mean      1.996585     2.947317      6.112683      5.561951  1971.732683
# ...

# %%
train[train['Garage Yr Blt'] == 2207]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area  Street  \
# 1699  2261  916384070           20        RL          68.0      8298       2
#
#      Lot Shape Land Contour Utilities Lot Config  Land Slope Neighborhood  \
# 1699       IR1          HLS    AllPub     Inside           3       Timber
#
#      Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 1699        Norm        Norm      1Fam      1Story             8
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 1699             5        2006            2007        Hip   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area  Exter Qual  \
# 1699      VinylSd      VinylSd         None           0.0           4
#
#       Exter Cond Foundation  Bsmt Qual  Bsmt Cond  Bsmt Exposure  \
# 1699           3      PConc          4          3              3
#
#       BsmtFin Type 1  BsmtFin SF 1  BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  \
# ...

# %%
train['Garage Yr Blt'].replace(2207.0,2007.0,inplace=True)

# %%
#Checking for any other discrepancy in garage built year.
train['Garage Yr Blt'].describe()
# Out:
# count    2050.000000
# mean     1869.540000
# std       452.312433
# min         0.000000
# 25%      1957.250000
# 50%      1978.000000
# 75%      2001.000000
# max      2010.000000
# Name: Garage Yr Blt, dtype: float64

# %%
train.to_csv(path_or_buf='../datasets/train_clean.csv',index=False)

# %% [markdown]
# Since the year built is 2007 and the year it was remodelled then sold was 2007, we can assume that the observation with the abnomaly in garage built to be the year it was remodelled which is 2007. This could be an input error during the data collection process.

# %% [markdown]
# ## Test DataFrame Cleaning

# %% [markdown]
# **Assigning values to ordinal columns**

# %%
test[['Paved Drive']] = test[['Paved Drive']].replace(['N','P','Y'],[0,1,2])

test[['Garage Finish']] = test[['Garage Finish']].replace([np.nan,'Unf','RFn','Fin'],[0,1,2,3])

test[['Alley']] = test[['Alley']].replace(['Grvl','Pave'],[1,2])

test[['Street']] = test[['Street']].replace(['Grvl','Pave'],[1,2])

test[['Land Slope']] = test[['Land Slope']].replace(['Sev','Mod','Gtl'],[1,2,3])

test[['Central Air']] = test[['Central Air']].replace(['N','Y'],[0,1])

test[['Functional']] = test[['Functional']].replace(['Sal','Sev','Maj2','Maj1','Mod','Min2','Min1','Typ'],[1,2,3,4,5,6,7,8])

test[['Fence']] = test[['Fence']].replace([np.nan,'MnWw','GdWo','MnPrv','GdPrv'],[0,1,2,3,4])

test[['BsmtFin Type 1','BsmtFin Type 2']] = test[['BsmtFin Type 1','BsmtFin Type 2']].replace([np.nan,'Unf','LwQ','Rec','BLQ','ALQ','GLQ'],[0,1,2,3,4,5,6])

test[['Bsmt Exposure']] = test[['Bsmt Exposure']].replace([np.nan,'No','Mn','Av','Gd'],[0,1,2,3,4])

test[['Exter Qual','Exter Cond','Bsmt Qual',
      'Bsmt Cond','Heating QC','Kitchen Qual',
      'Fireplace Qu','Garage Qual','Garage Cond',
     'Pool QC']] = test[['Exter Qual','Exter Cond','Bsmt Qual',
      'Bsmt Cond','Heating QC','Kitchen Qual',
      'Fireplace Qu','Garage Qual','Garage Cond',
     'Pool QC']].replace([np.nan,'Po','Fa','TA','Gd','Ex'],[0,1,2,3,4,5])

# %% [markdown]
# **Dealing with Missing Values**

# %%
#Visualising the missing values
plt.figure(figsize = (32,20))
sns.heatmap(test.isnull(),yticklabels=False,cbar=False,cmap='viridis');

# %%
null_columns = test.columns[test.isnull().sum()>0].tolist()
test[null_columns].isnull().sum()
# Out:
# Lot Frontage     160
# Alley            821
# Mas Vnr Type       1
# Mas Vnr Area       1
# Electrical         1
# Garage Type       44
# Garage Yr Blt     45
# Misc Feature     838
# dtype: int64

# %%
test[test['Mas Vnr Type'].isnull()][['Mas Vnr Type','Mas Vnr Area']]
# Out:
#     Mas Vnr Type  Mas Vnr Area
# 866          NaN           NaN

# %%
#Filling null values
test['Mas Vnr Type'].fillna('None',inplace=True)
test['Mas Vnr Area'].fillna(0,inplace=True)

# %%
test[test['Electrical'].isnull()][['Year Built']]
# Out:
#      Year Built
# 635        2006

# %%
test[test['Year Built'] == 2006][['Electrical']]
# Out:
#     Electrical
# 2        SBrkr
# 35       SBrkr
# 98       SBrkr
# 114      SBrkr
# 122      SBrkr
# 168      SBrkr
# 184      SBrkr
# 209      SBrkr
# 228      SBrkr
# 240      SBrkr
# 241      SBrkr
# 251      SBrkr
# 265      SBrkr
# 272      SBrkr
# 308      SBrkr
# 313      SBrkr
# 354      SBrkr
# 366      SBrkr
# 376      SBrkr
# 384      SBrkr
# 397      SBrkr
# 404      SBrkr
# 492      SBrkr
# 505      SBrkr
# 510      SBrkr
# 532      SBrkr
# 562      SBrkr
# 595      SBrkr
# 600      SBrkr
# 605      SBrkr
# 612      SBrkr
# 635        NaN
# 665      SBrkr
# 684      SBrkr
# 760      SBrkr
# 799      SBrkr
# 805      SBrkr
# 827      SBrkr
# 834      SBrkr

# %%
test['Electrical'].fillna('SBrkr',inplace=True)

# %% [markdown]
# Since the houses that were built in 2006 has the value SBrkr, we can assume the missing value in column 'Electrical' would have the same value.

# %%
test[(test['Garage Type'].notnull()) & (test['Garage Yr Blt'].isnull())]
# Out:
#        Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area  Street  \
# 765  1357  903426160           60        RM          57.0      8094       2
#
#      Alley Lot Shape Land Contour Utilities Lot Config  Land Slope  \
# 765    1.0       Reg          Lvl    AllPub     Inside           3
#
#     Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 765      OldTown        Norm        Norm    2fmCon      2.5Unf             6
#
#      Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 765             8        1910            1983      Gable   CompShg
#
#     Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area  Exter Qual  \
# 765      Wd Sdng      Wd Sdng         None           0.0           3
#
#      Exter Cond Foundation  Bsmt Qual  Bsmt Cond  Bsmt Exposure  \
# 765           3      PConc          3          3              2
#
#      BsmtFin Type 1  BsmtFin SF 1  BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  \
# ...

# %%
#Assigning value = to the year remodelled/added
test.at[765, 'Garage Yr Blt'] = 1983.0

# %% [markdown]
# The observation shows that there is a garage present. As such, we will assume that the Year built will ocincide with the remodelled year.

# %%
test[test['Garage Type'].isnull()][['Garage Type','Garage Yr Blt']]
# Out:
#     Garage Type  Garage Yr Blt
# 29          NaN            NaN
# 45          NaN            NaN
# 66          NaN            NaN
# 68          NaN            NaN
# 106         NaN            NaN
# 110         NaN            NaN
# 114         NaN            NaN
# 145         NaN            NaN
# 153         NaN            NaN
# 157         NaN            NaN
# 181         NaN            NaN
# 219         NaN            NaN
# 231         NaN            NaN
# 232         NaN            NaN
# 257         NaN            NaN
# 283         NaN            NaN
# 306         NaN            NaN
# 315         NaN            NaN
# 321         NaN            NaN
# 338         NaN            NaN
# 342         NaN            NaN
# 351         NaN            NaN
# 360         NaN            NaN
# 396         NaN            NaN
# 483         NaN            NaN
# 497         NaN            NaN
# 528         NaN            NaN
# 530         NaN            NaN
# 537         NaN            NaN
# ...

# %%
test['Garage Type'].fillna('None',inplace=True)
test['Garage Yr Blt'].fillna(0,inplace=True)

# %% [markdown]
# Since the null in Garage Type and Garage Yr Blt coincides, I have replaced the values to 'None' and 0 respectively.

# %%
test['Lot Frontage'].fillna(test['Lot Frontage'].mean(),inplace=True)

# %%
test.drop(columns=['Alley','Misc Feature'],inplace=True)

# %% [markdown]
# As the null values are too large, I have decided to drop these columns.

# %%
#Saving cleaned dataframe to csv
test.to_csv(path_or_buf='../datasets/test_clean.csv',index=False)
